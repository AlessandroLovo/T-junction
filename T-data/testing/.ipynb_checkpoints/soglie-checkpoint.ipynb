# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
#%matplotlib notebook

sig1=[]
sig2=[]
t = []
i=0

with open('C:/Users/Utente/T-junction/T-junction/T-data/18-11/B-ol15-aq25-pause10.csv') as data:
    for sig in csv.reader(data, delimiter='	'):
        #print(sig)
        sig[0] = sig[0].replace('.','').replace(',','.')
        sig[1] = sig[1].replace('.','').replace(',','.')
        sig[2] = sig[2].replace('.','').replace(',','.')
        #print(sig)
        sig1.append(float(sig[0]))
        sig2.append(float(sig[1]))
        t.append(float(sig[2]))
sig1 = np.array(sig1)
sig1 = sig1[0:-1]
sig2 = np.array(sig2)
sig2 = sig2[0:-1]
t = np.array(t)
t = t[0:-1]        

plt.figure()
plt.plot(sig2)
#plt.ylim(1.1,1.9 )
#plt.xlim(0, 500)
plt.show()

# %%
#"Rotate signal"
from lmfit.models import LinearModel
linear = LinearModel(prefix='lin_')
pars = linear.make_params(slope = 0, intercept=1.6)
init = linear.eval(pars, x=t)
out = linear.fit(sig1, pars, x=t)
print(out.fit_report())

plt.plot(t, sig1, color='blue')
plt.plot(t, out.init_fit, 'k--', label='initial fit')
plt.plot(t, out.best_fit, 'r-', label='best fit')
plt.legend(loc='best')
#plt.xlim(30, 150)
plt.show()

slope=out.best_values.get('lin_slope')
sig1[:]=sig1[:]-slope*t[:]
plt.figure()
plt.plot(t,sig1)
# Out:
# [[Model]]
#     Model(linear, prefix='lin_')
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 6
#     # data points      = 12607
#     # variables        = 2
#     chi-square         = 395.028517
#     reduced chi-square = 0.03133903
#     Akaike info crit   = -43654.6655
#     Bayesian info crit = -43639.7815
# [[Variables]]
#     lin_slope:     -6.4418e-04 +/- 1.7549e-05 (2.72%) (init = 0)
#     lin_intercept:  1.70063844 +/- 0.00311528 (0.18%) (init = 1.6)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(lin_slope, lin_intercept) = -0.862

# %%
#histogram plot
nbins =50
plt.figure()
freq,bins,p = plt.hist(sig1, nbins)

x = 0.5 *(bins[:-1] + bins[1:])
print(x,'\n')
print(bins)

plt.plot(x,freq)
# Out:
# [1.38885255 1.39955216 1.41025178 1.42095139 1.43165101 1.44235062
#  1.45305024 1.46374985 1.47444947 1.48514908 1.49584869 1.50654831
#  1.51724792 1.52794754 1.53864715 1.54934677 1.56004638 1.570746
#  1.58144561 1.59214523 1.60284484 1.61354445 1.62424407 1.63494368
#  1.6456433  1.65634291 1.66704253 1.67774214 1.68844176 1.69914137
#  1.70984099 1.7205406  1.73124021 1.74193983 1.75263944 1.76333906
#  1.77403867 1.78473829 1.7954379  1.80613752 1.81683713 1.82753674
#  1.83823636 1.84893597 1.85963559 1.8703352  1.88103482 1.89173443
#  1.90243405 1.91313366]
#
# [1.38350274 1.39420236 1.40490197 1.41560159 1.4263012  1.43700081
#  1.44770043 1.45840004 1.46909966 1.47979927 1.49049889 1.5011985
#  1.51189812 1.52259773 1.53329735 1.54399696 1.55469657 1.56539619
#  1.5760958  1.58679542 1.59749503 1.60819465 1.61889426 1.62959388
#  1.64029349 1.65099311 1.66169272 1.67239233 1.68309195 1.69379156
#  1.70449118 1.71519079 1.72589041 1.73659002 1.74728964 1.75798925
#  1.76868887 1.77938848 1.79008809 1.80078771 1.81148732 1.82218694
#  1.83288655 1.84358617 1.85428578 1.8649854  1.87568501 1.88638462
#  1.89708424 1.90778385 1.91848347]

# %%
#histogram fit

from lmfit.models import GaussianModel

for i in range(1,6):    #Cicle changing center1 position if condition (center1+2*sigma1 < center2-2*sigma2) is not fulfilled

    #linear = LinearModel(prefix='lin_')
    gauss1 = GaussianModel(prefix='g1_')
    pars = gauss1.make_params(center=x[0]+i*(x[-1]-x[0])/10, sigma=(x[-1]-x[0])/15 , amplitude=max(freq)/20)

    #gauss1 = GaussianModel(prefix='g1_')
    #pars.update(gauss1.make_params())

    gauss2 = GaussianModel(prefix='g2_')
    pars.update(gauss2.make_params())

    pars['g1_center'].set(max = x[0]+(x[-1]-x[0])*0.7, min=min(x))
    pars['g1_sigma'].set(max=(x[-1]-x[0])/10,min=(x[-1]-x[0])/30)
    #pars['g1_amplitude'].set(value=max(freq)/20,min=10)

    pars['g2_center'].set(value=x[-1]*0.98)
    pars['g2_sigma'].set(value=(x[-1]-x[0])/15)
    pars['g2_amplitude'].set(value=max(freq)/20,min=10)

    #mod = linear + gauss1 +gauss2
    mod = gauss1 +gauss2

    init = mod.eval(pars, x=x)
    out = mod.fit(freq, pars, x=x)
    print(out.fit_report())
    
    plt.figure()
    plt.plot(x, freq, color='blue')
    plt.plot(x, out.init_fit, 'k--', label='initial fit')
    plt.plot(x, out.best_fit, 'r-', label='best fit')
    plt.legend(loc='best')
    #plt.xlim(30, 150)
    plt.show()
    
    center2=out.best_values.get('g2_center')
    sigma2=out.best_values.get('g2_sigma')
    center1=out.best_values.get('g1_center')
    sigma1=out.best_values.get('g1_sigma')
    
    if center1+2*sigma1 < center2-2*sigma2:
        max_freq1=max(freq[x<center1+sigma1])
        x_max1 = x[np.argmax(freq[x<center1+2*sigma1])]
        max_freq2=max(freq[x>center2-sigma2])
        a=x>center2-sigma2
        freq2=np.zeros(len(freq))
        for i in range(len(a)): 
            if a[i]==True: freq2[i]=freq[i]
        #print(freq2)
        x_max2 = x[np.argmax(freq2)]
        print('xmax 1: ', x_max1,'\n xmax 2: ',x_max2)
        break
    else: print('trying again')
soglia_sig1_low = x_max1 +2*sigma1
soglia_sig1_high = x_max2 -2*sigma1
# Out:
# [[Model]]
#     (Model(gaussian, prefix='g1_') + Model(gaussian, prefix='g2_'))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 50
#     # data points      = 50
#     # variables        = 6
#     chi-square         = 170616.881
#     reduced chi-square = 3877.65639
#     Akaike info crit   = 418.757643
#     Bayesian info crit = 430.229781
# ##  Warning: uncertainties could not be estimated:
#     g1_sigma:      at initial value
# [[Variables]]
#     g1_amplitude:  49.6869300 (init = 69.55)
#     g1_center:     1.48518526 (init = 1.441281)
#     g1_sigma:      0.03495207 (init = 0.03495207)
#     g1_fwhm:       0.08230584 == '2.3548200*g1_sigma'
#     g1_height:     567.125661 == '0.3989423*g1_amplitude/max(2.220446049250313e-16, g1_sigma)'
#     g2_amplitude:  73.6090528 (init = 69.55)
#     g2_center:     1.85256804 (init = 1.874871)
#     g2_sigma:      0.02054388 (init = 0.03495207)
#     g2_fwhm:       0.04837715 == '2.3548200*g2_sigma'
#     g2_height:     1429.41650 == '0.3989423*g2_amplitude/max(2.220446049250313e-16, g2_sigma)'
# xmax 1:  1.5065483093198746
#  xmax 2:  1.848935973979208

# %%
#same for sig2
plt.figure()
plt.plot(t,sig2)
#plt.ylim(1.3, 2.1)
#plt.xlim(0, 500)
plt.show()

#"Rotate signal"
from lmfit.models import LinearModel
linear = LinearModel(prefix='lin_')
pars = linear.make_params(slope = 0, intercept=1.6)
init = linear.eval(pars, x=t)
out = linear.fit(sig2, pars, x=t)
print(out.fit_report())

plt.figure()
plt.plot(t, sig2, color='blue')
plt.plot(t, out.init_fit, 'k--', label='initial fit')
plt.plot(t, out.best_fit, 'r-', label='best fit')
plt.legend(loc='best')
#plt.xlim(30, 150)
plt.show()

slope=out.best_values.get('lin_slope')
sig2[:]=sig2[:]-slope*t[:]
plt.figure()
plt.plot(t,sig2)
# Out:
# [[Model]]
#     Model(linear, prefix='lin_')
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 6
#     # data points      = 12607
#     # variables        = 2
#     chi-square         = 556.814463
#     reduced chi-square = 0.04417409
#     Akaike info crit   = -39327.0086
#     Bayesian info crit = -39312.1246
# [[Variables]]
#     lin_slope:     -6.5202e-04 +/- 2.0835e-05 (3.20%) (init = 0)
#     lin_intercept:  1.59682886 +/- 0.00369861 (0.23%) (init = 1.6)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(lin_slope, lin_intercept) = -0.862

# %%
sig2[-2:]
# Out:
# array([1.81290943, 1.82792639])

# %%
#histogram plot
nbins =50
plt.figure()
freq,bins,p = plt.hist(sig2[0:-2], nbins)


x = 0.5 *(bins[:-1] + bins[1:])
print(x,'\n')
print(bins)

plt.plot(x,freq)
print(freq)
# Out:
# [1.23324164 1.24564077 1.2580399  1.27043903 1.28283816 1.29523729
#  1.30763642 1.32003555 1.33243468 1.34483381 1.35723294 1.36963207
#  1.3820312  1.39443033 1.40682946 1.41922859 1.43162772 1.44402685
#  1.45642598 1.46882511 1.48122424 1.49362337 1.5060225  1.51842163
#  1.53082076 1.54321989 1.55561902 1.56801815 1.58041727 1.5928164
#  1.60521553 1.61761466 1.63001379 1.64241292 1.65481205 1.66721118
#  1.67961031 1.69200944 1.70440857 1.7168077  1.72920683 1.74160596
#  1.75400509 1.76640422 1.77880335 1.79120248 1.80360161 1.81600074
#  1.82839987 1.840799  ]
#
# [1.22704208 1.23944121 1.25184034 1.26423947 1.2766386  1.28903773
#  1.30143686 1.31383599 1.32623512 1.33863425 1.35103338 1.36343251
#  1.37583164 1.38823076 1.40062989 1.41302902 1.42542815 1.43782728
#  1.45022641 1.46262554 1.47502467 1.4874238  1.49982293 1.51222206
#  1.52462119 1.53702032 1.54941945 1.56181858 1.57421771 1.58661684
#  1.59901597 1.6114151  1.62381423 1.63621336 1.64861249 1.66101162
#  1.67341075 1.68580988 1.69820901 1.71060814 1.72300727 1.7354064
#  1.74780553 1.76020466 1.77260378 1.78500291 1.79740204 1.80980117
#  1.8222003  1.83459943 1.84699856]
# [   6.   22.   84.  203.  297.  400.  534.  580.  646.  524.  391.  223.
#   167.  122.  101.   85.   84.   66.   74.   75.   56.   51.   65.   54.
#    53.   46.   49.   65.   60.   71.   78.   75.   83.   70.   62.   75.
#    55.   64.   70.   86.  145.  371.  871. 1295. 1431. 1209.  727.  354.
#   169.   61.]

# %%
#histogram fit

from lmfit.models import GaussianModel

for i in range(1,6):    #Cicle changing center1 position if condition (center1+2*sigma1 < center2-2*sigma2) is not fulfilled

    #linear = LinearModel(prefix='lin_')
    gauss1 = GaussianModel(prefix='g1_')
    pars = gauss1.make_params(center=x[0]+i*(x[-1]-x[0])/10, sigma=(x[-1]-x[0])/15 , amplitude=max(freq)/20)

    #gauss1 = GaussianModel(prefix='g1_')
    #pars.update(gauss1.make_params())

    gauss2 = GaussianModel(prefix='g2_')
    pars.update(gauss2.make_params())

    pars['g1_center'].set(max = x[0]+(x[-1]-x[0])*0.7, min=min(x))
    pars['g1_sigma'].set(max=(x[-1]-x[0])/10,min=(x[-1]-x[0])/30)
    #pars['g1_amplitude'].set(value=max(freq)/20,min=10)

    pars['g2_center'].set(value=x[-1]*0.98)
    pars['g2_sigma'].set(value=(x[-1]-x[0])/15)
    pars['g2_amplitude'].set(value=max(freq)/20,min=10)

    #mod = linear + gauss1 +gauss2
    mod = gauss1 +gauss2

    init = mod.eval(pars, x=x)
    out = mod.fit(freq, pars, x=x)
    print(out.fit_report())

    plt.plot(x, freq, color='blue')
    plt.plot(x, out.init_fit, 'k--', label='initial fit')
    plt.plot(x, out.best_fit, 'r-', label='best fit')
    plt.legend(loc='best')
    #plt.xlim(30, 150)
    plt.show()
    
    center2=out.best_values.get('g2_center')
    sigma2=out.best_values.get('g2_sigma')
    center1=out.best_values.get('g1_center')
    sigma1=out.best_values.get('g1_sigma')
    
    if center1+2*sigma1 < center2-2*sigma2:
        max_freq1=max(freq[x<center1+sigma1])
        x_max1 = x[np.argmax(freq[x<center1+sigma1])]
        max_freq2=max(freq[x>center2-sigma2])
        a=x>center2-sigma2
        freq2=np.zeros(len(freq))
        for i in range(len(a)): 
            if a[i]==True: freq2[i]=freq[i]
        #print(freq2)
        x_max2 = x[np.argmax(freq2)]
        print('xmax 1: ', x_max1,'\n xmax 2: ',x_max2)
        break
    else: print('trying again')
    
soglia_sig2_low = x_max1 +2*sigma1
soglia_sig2_high = x_max2 -2*sigma2
# Out:
# [[Model]]
#     (Model(gaussian, prefix='g1_') + Model(gaussian, prefix='g2_'))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 51
#     # data points      = 50
#     # variables        = 6
#     chi-square         = 136351.148
#     reduced chi-square = 3098.88972
#     Akaike info crit   = 407.548290
#     Bayesian info crit = 419.020428
# ##  Warning: uncertainties could not be estimated:
#     g1_sigma:      at initial value
# [[Variables]]
#     g1_amplitude:  57.3199502 (init = 71.55)
#     g1_center:     1.32617340 (init = 1.293997)
#     g1_sigma:      0.04050382 (init = 0.04050382)
#     g1_fwhm:       0.09537921 == '2.3548200*g1_sigma'
#     g1_height:     564.572693 == '0.3989423*g1_amplitude/max(2.220446049250313e-16, g1_sigma)'
#     g2_amplitude:  82.6539454 (init = 71.55)
#     g2_center:     1.77751572 (init = 1.803983)
#     g2_sigma:      0.02289172 (init = 0.04050382)
#     g2_fwhm:       0.05390588 == '2.3548200*g2_sigma'
#     g2_height:     1440.44022 == '0.3989423*g2_amplitude/max(2.220446049250313e-16, g2_sigma)'
# xmax 1:  1.332434681348483
#  xmax 2:  1.7788033496343356

# %%
print(soglia_sig1_low)
print(soglia_sig1_high)

plt.plot(sig1)
plt.plot(soglia_sig1_high*np.ones(len(t)), color='red')
plt.plot(soglia_sig1_low*np.ones(len(t)), color='red')
#plt.xlim(0,2000)
#plt.ylim(1.5,1.95)
plt.show()
# Out:
# 1.5764524575211551
# 1.7790318257779274

# %%
soglia_sig2_high*np.ones(len(x))
# Out:
# array([1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991,
#        1.73301991, 1.73301991, 1.73301991, 1.73301991, 1.73301991])

# %%
print(soglia_sig2_low)
print(soglia_sig2_high)

plt.plot(t,sig2)
plt.plot(t,soglia_sig2_high*np.ones(len(t)), color='red')
plt.plot(t,soglia_sig2_low*np.ones(len(t)), color='red')
#plt.xlim(330,380)
plt.show()
# Out:
# 1.4134423285559157
# 1.7330199082792226

# %%
#definisco una goccia da quando il segnale sale sopra la soglia alta a quando scende sotto la soglia bassa
bool_high1=sig1>soglia_sig1_high
bool_low1=sig1<soglia_sig1_low
print(bool_high1, len(bool_high1))
print(bool_low1, len(bool_low1))
# Out:
# [False False False ...  True  True  True] 12607
# [ True  True  True ... False False False] 12607

# %%
goccia_start1 =[0]
goccia_end1 = [1]
for i in range(len(sig1)-1):
    if bool_low1[i]==False and bool_high1[i]==False and bool_low1[i+1]==False and bool_high1[i+1]==True:
        if goccia_start1[-1:]<goccia_end1[-1:]:
            goccia_start1.append(i+1)
    elif bool_low1[i]==True and bool_high1[i]==False and bool_low1[i+1]==False and bool_high1[i+1]==True:
        if goccia_start1[-1:]<goccia_end1[-1:]:
            goccia_start1.append(i+1)
    elif bool_low1[i]==False and bool_high1[i]==True and bool_low1[i+1]==True and bool_high1[i+1]==False:
        if goccia_start1[-1:]>goccia_end1[-1:]:
            goccia_end1.append(i)
    elif bool_low1[i]==False and bool_high1[i]==False and bool_low1[i+1]==True and bool_high1[i+1]==False:
        if goccia_start1[-1:]>goccia_end1[-1:]:
            goccia_end1.append(i)

# %%
ymin=1
ymax=2

for j in range(12):
    plt.figure()
    for i in range(len(goccia_end1)):
        
        plt.vlines(goccia_start1[i], ymin, ymax, color='green')
        plt.vlines(goccia_end1[i], ymin, ymax, color='red')


    plt.plot(sig1)
    plt.xlim(j*1000,(j+1)*1000)
    plt.ylim(1,2)
    plt.show()

# %%
bool_high2=sig2>soglia_sig2_high
bool_low2=sig2<soglia_sig2_low
print(bool_high2, len(bool_high2))
print(bool_low2, len(bool_low2))
# Out:
# [ True  True  True ...  True  True  True] 12607
# [False False False ... False False False] 12607

# %%
goccia_start2 =[0]
goccia_end2 = [1]
for i in range(len(sig2)-1):
    if bool_low2[i]==False and bool_high2[i]==False and bool_low2[i+1]==False and bool_high2[i+1]==True:
        if goccia_start2[-1:]<goccia_end2[-1:]:
            goccia_start2.append(i+1)
    elif bool_low2[i]==True and bool_high2[i]==False and bool_low2[i+1]==False and bool_high2[i+1]==True:
        if goccia_start2[-1:]<goccia_end2[-1:]:
            goccia_start2.append(i+1)
    elif bool_low2[i]==False and bool_high2[i]==True and bool_low2[i+1]==True and bool_high2[i+1]==False:
        if goccia_start2[-1:]>goccia_end2[-1:]:
            goccia_end2.append(i)
    elif bool_low2[i]==False and bool_high2[i]==False and bool_low2[i+1]==True and bool_high2[i+1]==False:
        if goccia_start2[-1:]>goccia_end2[-1:]:
            goccia_end2.append(i)

# %%
ymin=1.
ymax=2.1
plt.plot(sig2)
plt.plot(0,500)
plt.ylim(ymin,ymax)

for i in range(len(goccia_end2)):
    #print(goccia_start2[i],goccia_end2[i])
    plt.vlines(goccia_start2[i], ymin, ymax, color='green')
    plt.vlines(goccia_end2[i], ymin, ymax, color='red')

plt.xlim(11000,11500)
plt.ylim(1,2)
plt.show()
