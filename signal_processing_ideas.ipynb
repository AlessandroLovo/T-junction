# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
# %matplotlib notebook

# %%
sig1=[]
sig2=[]
t = []
i=0

with open('T-data/12-11/B-ol5-aq35-pause10.csv') as data:
    for sig in csv.reader(data, delimiter='	'):
        #print(sig)
        sig[0] = sig[0].replace('.','').replace(',','.')
        sig[1] = sig[1].replace('.','').replace(',','.')
        sig[2] = sig[2].replace('.','').replace(',','.')
        #print(sig)
        sig1.append(float(sig[0]))
        sig2.append(float(sig[1]))
        t.append(float(sig[2]))
sig1 = np.array(sig1)
sig2 = np.array(sig2)
t = np.array(t)
        
plt.figure()
plt.plot(sig1)
# plt.ylim(1.5, 2.5)
# plt.xlim(0, 500)
plt.show()
        
# print(len(sig2))

plt.plot(clean(sig1,15))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def clean(vector, n_avg):
    return (np.convolve(vector, np.ones(n_avg))*(1./n_avg))[n_avg//2:]

# %%
nbins = 50

plt.figure()
plt.hist(sig1, bins=nbins)
freq, bins, pattume = plt.hist(clean(sig1,15), bins=nbins,alpha=0.5)

x = 0.5 *(bins[:-1] + bins[1:])

x_max1 = x[np.argmax(freq)]
# x_max2 = 0

max_freq1 = np.max(freq)
# max_freq2 = 0

# for i,f in enumerate(freq):
#     if f > max_freq2 and f < max_freq1:
#         x_max2 = x[i]
#         max_freq2 = f
        
print(x_max1, x_max2, max_freq1, max_freq2)


plt.plot(x,freq)
plt.plot([x_max1]*2,[0,max_freq1],color='black')
# plt.plot([x_max2]*2,[0,max_freq2],color='black')
# Out:
# <img src="data:image/png;base64,..." width="640">
# 1.865673333333333 1.88725 3073.0 4059.0

# %%
120/15
# Out:
# 8.0
