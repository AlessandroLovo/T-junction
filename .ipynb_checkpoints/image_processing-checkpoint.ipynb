# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
from lmfit.models import GaussianModel

import image_analysis as ia # module with most of the code
import drop_detection_tools as ddt

from importlib import reload

# reload(plt)
# %matplotlib notebook

# %%
# to do plots in latex

import matplotlib
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
#     'font.size' : 14.4,
    'font.size' : 17.28,
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %matplotlib notebook

# %% [markdown]
# ## Extract frames from video
#
# This needs to be done only once for every video

# %%
path = './T-data/12-11/'
video_name = 'B-ol5-aq5-funnel.wmv'

ia.extract_frames(path, video_name)

# %% [markdown]
# ## Get arrays from video

# %%
folder = './T-data/2-12/B-ol3-aq7-spf1'

spf = 1                    # seconds per frame in the video

color = 1 # green

arrays, mean_array = ia.get_arrays(folder,color)

print(arrays.shape)


# spannometric estimation velocity of the droplets

#********************************************************
radius  = 0.3  # capillary radius [mm]
flux_ol = 3   # oil flux   [uL/min] = [mm3/min]
flux_aq = 7   # water flux [uL/min] = [mm3/min]
#********************************************************

A  = np.pi*0.25*radius**2       # capillary area [mm2]
v  = (flux_ol + flux_aq)/A/60   # drops speed [mm/s]

print('v  = ', v,'\t[mm/s]')

Image.fromarray(mean_array).show()
# Out:
# (600, 960, 1280)
# v  =  2.3578510087688196 	[mm/s]

# %% [markdown]
# ## Subtract the mean

# %%
arrays_sub = ia.subtract_mean(arrays,mean_array, negative=True)
# Out:
# m = -76.0, M = 69.0

# %%
# see an example

idx = 9

Image.fromarray(arrays[idx]).show()
Image.fromarray(arrays_sub[idx]).show()

# %%
# see the corresponding negative image

neg = 255 - arrays_sub[idx]
Image.fromarray(neg).show()

# %% [markdown]
# ## Rotation and gaussian filter

# %%
# test on one image

rotation = 19
filter_size = 0 # y and x sigmas for the filter

img = ia.preprocess(arrays_sub[idx], rotation=rotation, filter_size=filter_size)
img.show()

# %%
# apply to all images
imgs = []
for array_sub in tqdm(arrays_sub):
    imgs.append(ia.preprocess(array_sub, rotation=rotation, filter_size=filter_size))

imgs = np.array(imgs,dtype=Image.Image)
# calibration image
calibr_img = ia.preprocess(arrays[idx], rotation=rotation, filter_size=0) # keep the image sharp

calibr_img.show()
# Out:
# 100%|██████████| 600/600 [00:02<00:00, 268.51it/s]

# %% [markdown]
# ## Channel analyzer

# %% [markdown]
# ### Calibrate

# %%
c = ia.Channel_analyzer()

# %%
c.calibrate(calibr_img,15)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c.find_channel(calibr_img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c.measure_distance(calibr_img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Save calibration

# %%
c.save(name='calibr_B-ol3-aq7',folder='./T-data/2-12/')

# %% [markdown]
# ### Load from existing calibration

# %%
c.load(name='calibr_B-ol15-aq15',folder='./T-data/19-11')

# %% [markdown]
# ### Try waveform extraction on one image

# %%
idx = 9

img = imgs[idx]
s, mean, std = c.evaluate(img)

plt.figure()
plt.plot(s,mean, color='blue')
plt.plot(s,mean - std,color='red',alpha=0.2)
plt.plot(s,mean + std,color='green',alpha=0.2)

plt.xlabel('s [mm]')
plt.ylabel('luminosity')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'luminosity')

# %% [markdown]
# ## Extract the waveforms

# %%
s     = 0.
means = []
stds  = []

for idx in tqdm(range(len(imgs))):
    s, mean, std = c.evaluate(imgs[idx])
    means.append(mean)
    stds.append(std)
# Out:
# 100%|██████████| 600/600 [00:30<00:00, 19.65it/s]

# %% [markdown]
# ## Threshold searching and drop computing functions

# %%
# see drop_detection_tools

# %% [markdown]
# ## Thresholds searching

# %%
# Luminosity thresholds searching

#**************************************************
idx         = 9     # Frame index (checking plots)
nbins       = 50    # Histo bins number
plot_switch = True  # Plots activation

high_sigmas = 4
low_sigmas = 1.5

# Not needed
# ymin      = 120   # Plot min. luminosity
# ymax      = 130   # Plot max. luminosity
#**************************************************

# %matplotlib inline

# Plot one single signal (checking)
thr_low, thr_high = ddt.thr_searcher(Ydata=means[idx], nbins=nbins, plot_switch=plot_switch, Xdata=s,
                                     high_sigmas=high_sigmas, low_sigmas=low_sigmas)

# %% [markdown]
# ### Compute thr for every image
#
# Can produce errors

# %%
#for all images
thrs_low  = []    # thr_low array
thrs_high = []    # thr_high array

for mean in tqdm(means):
    thr_low, thr_high = ddt.thr_searcher(Xdata=s, Ydata=mean, nbins=nbins, plot_switch=False)
    thrs_low.append(thr_low)
    thrs_high.append(thr_high)
# Out:
#   1%|          | 4/360 [00:00<00:23, 15.02it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#   3%|▎         | 12/360 [00:00<00:21, 16.05it/s]
# WARNING: thr_low > thr_high
#   5%|▌         | 18/360 [00:01<00:21, 15.59it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#   6%|▌         | 20/360 [00:01<00:22, 15.08it/s]
# WARNING: thr_low > thr_high
#   7%|▋         | 24/360 [00:01<00:27, 12.14it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#   8%|▊         | 28/360 [00:01<00:24, 13.29it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#   9%|▉         | 32/360 [00:02<00:23, 13.96it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  10%|█         | 36/360 [00:02<00:22, 14.28it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  11%|█         | 40/360 [00:02<00:21, 15.12it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  12%|█▏        | 44/360 [00:03<00:21, 15.01it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  13%|█▎        | 46/360 [00:03<00:21, 14.60it/s]
# WARNING: thr_low > thr_high
#  14%|█▍        | 50/360 [00:03<00:28, 10.89it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  15%|█▌        | 54/360 [00:03<00:25, 12.00it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  16%|█▌        | 58/360 [00:04<00:23, 13.13it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  17%|█▋        | 60/360 [00:04<00:23, 12.76it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  18%|█▊        | 64/360 [00:04<00:22, 13.32it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  19%|█▉        | 70/360 [00:05<00:21, 13.61it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  21%|██        | 74/360 [00:05<00:21, 13.49it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  21%|██        | 76/360 [00:05<00:21, 13.17it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  23%|██▎       | 82/360 [00:06<00:19, 14.23it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  24%|██▍       | 88/360 [00:06<00:23, 11.61it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  26%|██▌       | 92/360 [00:07<00:21, 12.41it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  27%|██▋       | 98/360 [00:07<00:18, 14.44it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  29%|██▉       | 104/360 [00:07<00:16, 15.82it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  31%|███       | 110/360 [00:08<00:15, 16.52it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  32%|███▏      | 114/360 [00:08<00:14, 16.75it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  33%|███▎      | 120/360 [00:08<00:14, 16.89it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#
/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  92%|█████████▏| 330/360 [00:22<00:01, 16.44it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  93%|█████████▎| 334/360 [00:23<00:02,  9.14it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  94%|█████████▍| 340/360 [00:23<00:01, 13.12it/s]
# WARNING: thr_low > thr_high
#  96%|█████████▌| 344/360 [00:24<00:01, 14.71it/s]
# WARNING: thr_low > thr_high
#  97%|█████████▋| 350/360 [00:24<00:00, 15.98it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  98%|█████████▊| 354/360 [00:24<00:00, 15.41it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high
#  99%|█████████▉| 358/360 [00:24<00:00, 16.21it/s]
# WARNING: thr_low > thr_high
# 100%|██████████| 360/360 [00:25<00:00, 14.32it/s]
# WARNING: thr_low > thr_high
# WARNING: thr_low > thr_high

# %%
print(f'thrs_low: \t mean = {np.mean(thrs_low)}  \t std = {np.std(thrs_low,ddof=1)}')
print(f'thrs_high:\t mean = {np.mean(thrs_high)} \t std = {np.std(thrs_high,ddof=1)}')
# Out:
# thrs_low: 	 mean = 122.18641036257678  	 std = 0.2538114366186062
# thrs_high:	 mean = 123.10704569730733 	 std = 1.6956861158985166

# %% [markdown]
# ### Compute the thresholds using all data at once

# %%
nbins       = 50    # Histo bins number
plot_switch = True  # Plots activation

high_sigmas = 2
low_sigmas = 2

thr_low, thr_high = ddt.thr_searcher(Ydata=np.concatenate(means), nbins=nbins, plot_switch=plot_switch,
                                     high_sigmas=high_sigmas, low_sigmas=low_sigmas)

# %% [markdown]
# ## Drop detection

# %%
thr_low = 177.5
thr_low = 176

# %%
# Detection of the edges of the drops

#**************************************************
idx         = 288# Frame index (checking plot)
plot_switch = True  # Plots activation
# Not needed
# xrange    = 35    # Plot x max.
# ymin      = 120   # Plot min. luminosity 
# ymax      = 130   # Plot max luminosity 
#**************************************************

# Plot one single signal (checking)
# %matplotlib inline
drop_start, drop_end = ddt.drop_det(Xdata=s, Ydata=means[idx],
                                    thr_low=thr_low, thr_high=thr_high, plot_switch=plot_switch)
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %% [markdown]
# ### Compute starts and ends for every frame

# %%
#for all images
drop_starts = []    # drop_start array
drop_ends   = []    # drop_end array

for mean in means:
    drop_start, drop_end = ddt.drop_det(Xdata=s, Ydata=mean, thr_low=thr_low, thr_high=thr_high, plot_switch=False)
    drop_starts.append(drop_start)
    drop_ends.append(drop_end)

# %%
drop_starts
# Out:
# [array([ 0.41776369,  9.36670169, 17.69985002]),
#  array([ 3.62794784, 12.48888554, 20.82478858]),
#  array([ 2.44061946,  7.18993299, 16.00683624, 24.23716438]),
#  array([ 0.94546519,  9.01490069, 17.7438244 ]),
#  array([ 2.04484333, 11.47747471, 20.16432875]),
#  array([ 0.21987563, 10.20221758, 19.4158076 ]),
#  array([ 5.16707722, 15.06138699]),
#  array([ 5.78272898, 16.13875939]),
#  array([ 8.64111213, 18.90945506]),
#  array([ 0.48372638, 11.47747471, 21.793463  ]),
#  array([ 2.33068164, 13.25843725]),
#  array([ 4.15564934, 15.0174126 ]),
#  array([ 5.98061704, 16.82036234]),
#  array([ 1.51714182, 12.18106485]),
#  array([ 6.44235586, 17.01824707]),
#  array([10.00433285, 20.51657399]),
#  array([ 4.02372397, 14.51170719]),
#  array([ 1.67105476, 12.22503923]),
#  array([ 2.44061946, 13.14850129]),
#  array([ 7.14595786, 17.76581159]),
#  array([ 9.49862707, 20.03223678]),
#  array([ 4.13366178, 14.59965596]),
#  array([10.81785895, 21.13300317]),
#  array([ 6.13452998, 16.79837515]),
#  array([ 8.48719919, 19.06356236]),
#  array([ 2.55055727, 13.74215548]),
#  array([ 0.81353982,  4.66136328, 15.80895151]),
#  array([10.35612792, 21.35315644]),
#  array([10.9717693]),
#  array([11.25760279]),
#  array([ 0.81353982, 12.13709047]),
#  array([ 1.36322888, 12.73074465]),
#  array([ 1.69304232, 12.99459095]),
#  array([ 2.61651996, 13.89606582]),
#  array([ 3.49602246, 14.73157911]),
#  array([ 4.46347522, 15.63305398]),
#  array([ 4.72732597, 15.96286186]),
#  array([ 5.01316429, 16.22670816]),
#  array([ 5.32099016, 16.55651604]),
#  array([ 5.93664192, 17.08420864]),
#  array([ 6.22248023, 17.41401652]),
#  array([ 6.81614442, 17.98568351]),
#  array([ 7.1239703, 18.2935042]),
#  array([ 7.43179618, 18.57933769]),
#  array([ 7.71763449, 18.86542441]),
#  array([ 8.04744793, 19.12960834]),
#  array([ 8.37726137, 19.48185359]),
#  array([ 8.61912456, 19.74603752]),
#  array([ 8.948938  , 20.18634407]),
#  array([ 9.23477632, 20.34045137]),
#  array([ 9.54260182, 20.64866596]),
#  array([10.136256]),
#  array([10.46606388]),
#  array([10.72991019]),
#  array([11.05971806]),
#  array([11.34555156]),
#  array([ 0.26385075, 11.63138505]),
#  array([ 0.48372638, 11.91721855]),
#  array([ 0.81353982, 12.22503923]),
#  array([ 0.81353982, 12.22503923]),
#  array([ 1.1213657 , 12.51087273]),
#  array([ 1.42919157, 12.79670622]),
#  array([ 1.73701745, 13.08253972]),
#  array([ 2.06683089, 13.3903604 ]),
#  array([ 2.33068164, 13.69818109]),
#  array([ 2.63850752, 13.98401459]),
#  array([ 2.9463334 , 14.24786089]),
#  array([ 3.23217171, 14.55568158]),
#  array([ 3.51801003, 14.84151507]),
#  array([ 3.8258359 , 15.12734856]),
#  array([ 4.13366178, 15.45715644]),
#  array([ 4.46347522, 15.74298994]),
#  array([ 4.74931353, 16.02882343]),
#  array([ 5.34297773, 16.62247761]),
#  array([ 5.6508036 , 16.88632392]),
#  array([ 5.95862948, 17.1941446 ]),
#  array([ 6.53030611, 17.78779878]),
#  array([ 6.81614442, 18.05164509]),
#  array([ 7.14595786, 18.35946577]),
#  array([ 7.45378374, 18.64529927]),
#  array([ 7.71763449, 18.93147039]),
#  array([ 8.04744793, 19.23968498]),
#  array([ 8.33328625, 19.52588424]),
#  array([ 8.64111213, 19.8120835 ]),
#  array([ 8.948938  , 20.12029809]),
#  array([ 9.23477632, 20.42851268]),
#  array([9.85042251]),
#  array([10.44407669]),
#  array([11.03773087]),
#  array([ 0.43975125, 11.63138505]),
#  array([ 1.01142788, 12.20305204]),
#  array([ 2.26471895, 13.34638602]),
#  array([ 4.28757472, 15.34722048]),
#  array([ 4.37552497, 15.23728452]),
#  array([ 5.4749031 , 16.13875939]),
#  array([ 8.48719919, 19.04154703]),
#  array([ 8.7730375 , 19.32774629]),
#  array([ 8.7730375 , 19.32774629]),
#  array([ 9.05887582, 19.65797621]),
#  array([ 6.2444678 ,  9.34471413, 20.03223678]),
#  array([ 9.65253778, 20.03223678]),
#  array([ 9.63055059, 20.23037473]),
#  array([ 9.96035847, 20.49455866]),
#  array([10.29016635, 20.80277325]),
#  array([10.29016635, 20.80277325]),
#  array([10.55401265, 21.08897251]),
#  array([ 0.10993781, 10.86183334]),
#  array([ 0.10993781, 10.86183334]),
#  array([ 0.39577613, 11.16965402]),
#  array([ 0.76956469, 11.45548752]),
#  array([ 2.22074383, 12.92862938]),
#  array([ 2.48459458, 13.17048849]),
#  array([ 2.79242046, 13.50029636]),
#  array([ 2.79242046, 13.50029636]),
#  array([ 3.10024633, 13.78612986]),
#  array([ 3.40807221, 14.04997616]),
#  array([ 3.40807221, 14.04997616]),
#  array([ 3.67192296, 14.33580966]),
#  array([ 3.97974884, 14.62164315]),
#  array([ 4.28757472, 14.92946384]),
#  array([ 4.28757472, 14.92946384]),
#  array([ 4.57341303, 15.19331014]),
#  array([ 4.88123891, 15.47914363]),
#  array([ 5.16707722, 15.76497713]),
#  array([ 5.16707722, 15.76497713]),
#  array([ 5.45291554, 16.07279782]),
#  array([ 5.78272898, 16.35863131]),
#  array([ 6.04657973, 16.62247761]),
#  array([ 6.35440561, 16.90831111]),
#  array([ 6.35440561, 16.88632392]),
#  array([ 6.64024392, 17.21613179]),
#  array([ 6.92608224, 17.4799781 ]),
#  array([ 6.92608224, 17.4799781 ]),
#  array([ 7.21192055, 17.76581159]),
#  array([ 7.49775887, 18.05164509]),
#  array([ 7.49775887, 18.05164509]),
#  array([ 7.82757231, 18.33747858]),
#  array([ 8.11341062, 18.64529927]),
#  array([ 8.11341062, 18.64529927]),
#  array([ 8.4212365 , 18.93147039]),
#  array([ 8.72906238, 19.23968498]),
#  array([ 9.01490069, 19.50386891]),
#  array([ 9.34471413, 19.9661908 ]),
#  array([ 9.34471413, 19.9661908 ]),
#  array([ 9.6085634 , 20.23037473]),
#  array([ 9.8724097 , 20.45052801]),
#  array([ 9.8724097 , 20.47254333]),
#  array([10.18023039, 20.89083456]),
#  array([10.51003827, 20.89083456]),
#  array([10.51003827, 21.08897251]),
#  array([ 0.04397513, 10.83984615, 21.28711046]),
#  array([ 0.37378857, 11.12567964]),
#  array([ 0.37378857, 11.12567964]),
#  array([ 0.61565175, 11.41151313]),
#  array([ 0.96745276, 11.67535944]),
#  array([ 0.96745276, 11.67535944]),
#  array([ 1.20931595, 12.00516732]),
#  array([ 1.53912939, 12.312988  ]),
#  array([ 1.53912939, 12.312988  ]),
#  array([ 1.8249677, 12.5988215]),
#  array([ 2.13279358, 12.90664218]),
#  array([ 2.15478114, 12.88465499]),
#  array([ 2.44061946, 13.17048849]),
#  array([ 2.70447021, 13.47830917]),
#  array([ 3.05627121, 13.74215548]),
#  array([ 3.05627121, 13.74215548]),
#  array([ 3.34210952, 14.04997616]),
#  array([ 3.62794784, 14.33580966]),
#  array([ 3.62794784, 14.33580966]),
#  array([ 3.91378615, 14.62164315]),
#  array([ 4.22161203, 14.88548945]),
#  array([ 4.22161203, 14.88548945]),
#  array([ 4.52943791, 15.21529733]),
#  array([ 4.7713011 , 15.52311802]),
#  array([ 5.10111454, 15.76497713]),
#  array([ 5.10111454, 15.76497713]),
#  array([ 5.40894041, 16.09478501]),
#  array([ 5.71676629, 16.3806185 ]),
#  array([ 6.00260461, 16.62247761]),
#  array([ 6.00260461, 16.62247761]),
#  array([ 6.33241805, 16.9302983 ]),
#  array([ 6.61825636, 17.23811899]),
#  array([ 6.61825636, 17.23811899]),
#  array([ 6.90409467, 17.52395248]),
#  array([ 7.21192055, 17.78779878]),
#  array([ 7.49775887, 17.78779878]),
#  array([ 7.49775887, 18.09561947]),
#  array([ 7.80558474, 18.40344016]),
#  array([ 7.80558474, 18.40344016]),
#  array([ 8.09142306, 18.71131711]),
#  array([ 8.39924894, 19.0195317 ]),
#  array([ 8.39924894, 19.0195317 ]),
#  array([ 8.70707481, 19.32774629]),
#  array([ 9.01490069, 19.59193022]),
#  array([ 6.2444678 ,  9.32272657, 19.87812949]),
#  array([ 9.32272657, 19.87812949]),
#  array([ 9.58657621, 20.18634407]),
#  array([ 9.89439689, 20.42851268]),
#  array([ 9.89439689, 20.42851268]),
#  array([ 6.5962688 , 10.24619196, 21.02292653]),
#  array([10.53202546, 21.04494186]),
#  array([10.53202546, 21.04494186]),
#  array([10.81785895, 21.33114112]),
#  array([ 0.26385075, 11.12567964]),
#  array([ 0.26385075, 11.12567964]),
#  array([ 0.5277015 , 11.41151313]),
#  array([ 0.83552738, 11.74132101]),
#  array([ 0.83552738, 11.74132101]),
#  array([ 1.14335326, 12.00516732]),
#  array([ 1.45117914, 12.29100081]),
#  array([ 1.75900501, 12.5768343 ]),
#  array([ 2.04484333, 12.88465499]),
#  array([ 2.04484333, 12.88465499]),
#  array([ 2.33068164, 13.14850129]),
#  array([ 2.33068164, 13.14850129]),
#  array([ 2.63850752, 13.47830917]),
#  array([ 2.96832096, 13.74215548]),
#  array([ 2.96832096, 13.74215548]),
#  array([ 3.23217171, 14.02798897]),
#  array([ 3.53999759, 14.33580966]),
#  array([ 3.60596028, 14.33580966]),
#  array([ 3.8258359 , 14.62164315]),
#  array([ 4.11167422, 14.90747665]),
#  array([ 4.11167422, 14.90747665]),
#  array([ 4.39751253, 15.19331014]),
#  array([ 4.70533841, 15.47914363]),
#  array([ 4.70533841, 15.47914363]),
#  array([ 5.01316429, 15.74298994]),
#  array([ 5.2990026 , 16.05081062]),
#  array([ 5.2990026 , 16.05081062]),
#  array([ 5.60682848, 16.31465693]),
#  array([ 5.89266679, 16.62247761]),
#  array([ 5.89266679, 16.62247761]),
#  array([ 6.15651754, 16.88632392]),
#  array([ 6.48633098, 17.17215741]),
#  array([ 6.48633098, 17.17215741]),
#  array([ 6.7721693, 17.4799781]),
#  array([ 7.05800761, 17.78779878]),
#  array([ 7.05800761, 17.78779878]),
#  array([ 7.36583349, 18.05164509]),
#  array([ 7.67365937, 18.33747858]),
#  array([ 7.67365937, 18.33747858]),
#  array([ 8.00347281, 18.66728646]),
#  array([ 8.26732356, 18.93147039]),
#  array([ 8.57514944, 19.26170031]),
#  array([ 8.88297531, 19.52588424]),
#  array([ 8.88297531, 19.52588424]),
#  array([ 9.16881363, 19.8120835 ]),
#  array([ 9.49862707, 20.23037473]),
#  array([ 9.49862707, 20.23037473]),
#  array([ 9.76247374, 20.51657399]),
#  array([10.11426881, 20.73672727]),
#  array([10.11426881, 20.73672727]),
#  array([10.37811512, 20.97889587]),
#  array([10.6859358 , 21.33114112]),
#  array([10.6859358 , 21.33114112]),
#  array([10.99375649]),
#  array([ 0.15391294, 11.27958998]),
#  array([ 0.15391294, 11.27958998]),
#  array([ 0.43975125, 11.60939786]),
#  array([ 0.72558957, 11.60939786]),
#  array([ 0.72558957, 11.87324416]),
#  array([ 1.03341544, 12.15907766]),
#  array([ 1.36322888, 12.44491115]),
#  array([ 1.36322888, 12.44491115]),
#  array([ 1.60509207, 12.75273184]),
#  array([ 1.60509207, 12.75273184]),
#  array([ 1.93490551, 13.01657814]),
#  array([ 2.24273139, 13.32439883]),
#  array([ 2.24273139, 13.32439883]),
#  array([ 2.52856971, 13.61023232]),
#  array([ 2.83639558, 13.89606582]),
#  array([ 2.83639558, 13.89606582]),
#  array([ 3.14422146, 14.18189931]),
#  array([ 3.43005977, 14.46773281]),
#  array([ 3.43005977, 14.46773281]),
#  array([ 3.71589809, 14.73157911]),
#  array([ 4.0017364, 15.0174126]),
#  array([ 4.33154984, 15.34722048]),
#  array([ 4.33154984, 15.34722048]),
#  array([ 4.5954006 , 15.61106679]),
#  array([ 4.90322647, 15.91888747]),
#  array([ 5.16707722, 16.18273378]),
#  array([ 5.16707722, 16.18273378]),
#  array([ 5.49689066, 16.46856727]),
#  array([ 5.49689066, 16.46856727]),
#  array([ 5.80471654, 16.75440076]),
#  array([ 6.06856729, 17.08420864]),
#  array([ 6.06856729, 17.08420864]),
#  array([ 6.39838073, 17.34805495]),
#  array([ 6.68421905, 17.63388844]),
#  array([ 6.99204493, 17.91972193]),
#  array([ 6.99204493, 17.91972193]),
#  array([ 7.27788324, 18.31549139]),
#  array([ 7.56372155, 18.51337612]),
#  array([ 7.56372155, 18.51337612]),
#  array([ 7.82757231, 18.7773631 ]),
#  array([ 8.20136087, 19.08557769]),
#  array([ 8.20136087, 19.08557769]),
#  array([ 8.48719919, 19.34976162]),
#  array([ 8.7730375 , 19.67999154]),
#  array([ 8.7730375 , 19.67999154]),
#  array([ 9.05887582, 19.98820612]),
#  array([ 9.36670169, 20.27440538]),
#  array([ 9.36670169, 20.27440538]),
#  array([ 9.67452497, 20.56060465]),
#  array([10.00433285, 20.91284989]),
#  array([10.00433285, 20.91284989]),
#  array([10.29016635, 21.17703382]),
#  array([10.61997423]),
#  array([10.61997423])]

# %%
reload(plt)
# Out:
# <module 'matplotlib.pyplot' from '/home/alessandro/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
# %matplotlib notebook
# %matplotlib notebook

distances = [(i,np.array(start[1:]) - np.array(start[:-1])) for i,start in enumerate(drop_starts) if len(start) > 1]


plt.figure(figsize=(12,8))
plt.plot([d[0] for d in distances], [d[1][0] for d in distances])
plt.xlabel('frame index')
plt.ylabel('distance between consecutive droplets')
# Out:
# <img src="data:image/png;base64,..." width="864">
# Text(0, 0.5, 'distance between consecutive droplets')

# %% [markdown]
# ## Velocity computing

# %% [markdown]
# ### Simple velocity estimation

# %%
#******************************************************************************
imgs_switch = False        # Images activation

nbins       = 100          # Velocity histogram bins number
thr         = 6.           # Min. velocity acceptable [mm/s] 
vec         = drop_starts  # Velocity computed on 'drop_starts' or 'drop_ends'
#******************************************************************************

diffs = []

# iterate over frames
for idx in tqdm(range(len(vec) - 1)):
    delay_idx = -1
    exit = False
    diffs.append([])
    # iterate over droplets in a frame
    for i,drop in enumerate(vec[idx]):
        diff = 0.
        # look for the same droplet in the next frame
        while(diff < thr):
            delay_idx += 1
            try:
                diff = vec[idx + 1][delay_idx] - drop
            except(IndexError):
                exit = True
                break
        if exit:
            if len(diffs[-1]) == 1:
                if imgs_switch == True:
                    imgs[idx].show()
            break
        diffs[-1].append(diff)
        
velocities = np.concatenate(diffs)/spf
        
# Plot 
plt.figure()
plt.hist(velocities, bins = nbins, color='green')
plt.title('Velocities spectrum')
plt.xlabel('Velocity [mm/s]')
plt.ylabel('Number of events')
# Out:
# 100%|██████████| 298/298 [00:00<00:00, 136437.35it/s]
# Text(0, 0.5, 'Number of events')

# %%
plt.figure()
plt.plot([len(diff) for diff in diffs])

plt.ylabel('velocity [mm/s]')
# Out:
# Text(0, 0.5, 'velocity [mm/s]')

# %%
# Velocity fitting

#**************************************************
nbins = 100   # Histo bins number
k     = 2     
#**************************************************
  
# Histogram definition
freq,bins,p = plt.hist(velocities, nbins, color='green') 
x = 0.5 *(bins[:-1] + bins[1:]) 


# Fit highest peak ----------------------------------------------------------

# Max 1 finding
xmax1 = x[np.nonzero(freq==max(freq))]

# Fit
gauss1  = GaussianModel(prefix='g1_')
pars1   = gauss1.make_params(center=xmax1[1], sigma=0.4 , amplitude=max(freq))
result1 = gauss1.fit(freq, pars1, x=x)


# Fit lower peak -------------------------------------------------------------

# Max 2 finding
center1 = result1.best_values.get('g1_center')
sigma1  = result1.best_values.get('g1_sigma')
freq2   = freq 
i       = 0
while( i < len(freq)):
    if (x[i] > center1-k*sigma1) and (x[i] < center1+k*sigma1):
        freq2[i] = 0
    i = i+1
xmax2 = x[np.nonzero(freq2==max(freq2))]
    
# Fit    
gauss2  = GaussianModel(prefix='g2_')
pars2   = gauss2.make_params(center=xmax2[0], sigma=0.4 , amplitude=max(freq))
result2 = gauss2.fit(freq, pars2, x=x)


# Plot ------------------------------------------------------------------------

# %matplotlib inline
plt.figure()
plt.figure(figsize=(20,8))
plt.hist(velocities, nbins, color='green')
plt.plot(x, result1.init_fit, 'k--', lw=2, label='initial fit highest peak')
plt.plot(x, result1.best_fit, 'k-', lw=2, label='best fit highest peak')
plt.plot(x, result2.init_fit, 'b--', lw=2, label='initial fit highest peak')
plt.plot(x, result2.best_fit, 'b-', lw=2, label='best fit shortest peak')
#plt.plot(x, freq2, color='yellow', label='exp. data for shortest peak fit')
plt.legend(loc='best')
plt.title("Velocities spectrum")
plt.xlabel("Velocity [mm/s]")
plt.ylabel("Number of events") 
plt.legend()

# %% [markdown]
# ## Following the droplets along the video
#
# A better alternative to Simple velocity estimation

# %%
# DO NOT TRANSFER TO .py file !!!! uses local variables

class Droplet():
    def __init__(self,ID):
        self.ID = ID
        self.frames = [] # frame IDs in which the droplet appears
        self.index_in_frame = [] # index of the droplet in every frame in which it appears
        
        self.starts = []
        self.ends = []
        
        self.sizes = None
        self.velocities = None
        
    @property
    def recurrence(self):
        return len(self.frames) # number of frames in which the droplet is visible
    
    @property
    def size(self):
        self.sizes = np.array(self.ends) - np.array(self.starts)
        return np.mean(self.sizes), np.std(self.sizes)
    
    @property
    def velocity(self):
        if len(self.frames) > 1:
            self.velocities = (np.array(self.starts[:-1]) - np.array(self.starts[1:]))/spf
            return np.mean(self.velocities), np.std(self.velocities)
        else:
            return np.nan, np.nan
        
    def add(self, frame_id, idx_in_frame, velocity_range=None, size_perc_tolerance=None):
        '''
        Tries to add a new frame to the droplet. Returns True if it manages to.
        '''
        start = drop_starts[frame_id][idx_in_frame]
        end = drop_ends[frame_id][idx_in_frame]
        
        if len(self.frames) > 0:
        
            # check if velocity is meaningful
            if velocity_range is not None:
                velocity = (self.starts[-1] - start)/spf
                if velocity < velocity_range[0]:
                    return False
                if velocity > velocity_range[1]:
                    return False

            # check if size is similar to the previous one
            if size_perc_tolerance is not None:
                old_size = self.ends[-1] - self.starts[-1]
                size = end - start
                if np.abs(size - old_size) > old_size*size_perc_tolerance:
                    return False
                
        self.frames.append(frame_id)
        self.index_in_frame.append(idx_in_frame)
        self.starts.append(start)
        self.ends.append(end)
        return True

# %%
velocity_range = [0, 5]
size_perc_tolerance = 0.5


droplets = []
drop_idx = 0

# create ID mask
ID_mask = []
for drop_start in drop_starts:
    ID_mask.append([-1]*len(drop_start))

# iterate over frame
for idx in tqdm(range(len(drop_starts) - 1)):
    frame_idx = len(drop_starts) - 1 - idx # go reversed
    # iterate over droplets in a frame
    for i,start in enumerate(drop_starts[frame_idx]):
        # detect if droplet is already present
        drop_ID = ID_mask[frame_idx][i]
        if drop_ID == -1: # add new droplet
            ID_mask[frame_idx][i] = drop_ID = drop_idx
            droplets.append(Droplet(drop_idx))
            droplets[drop_idx].add(frame_idx,i)
            drop_idx += 1
        
        # now all droplets in this frame have a valid ID
        # we try to find them in the previous frame (remember we are looking the video in reverse)
        prev_frame_idx = frame_idx - 1
        for prev_i,prev_start in enumerate(drop_starts[prev_frame_idx]):
            if ID_mask[prev_frame_idx][prev_i] != -1: # droplet already assigned
                continue
            if droplets[drop_ID].add(prev_frame_idx,prev_i,
                                     velocity_range=velocity_range, size_perc_tolerance=size_perc_tolerance):
                ID_mask[prev_frame_idx][prev_i] = drop_ID # assign droplet
                break
                
droplets = np.array(droplets,dtype=Droplet)
                
def drops_in_frame(frame_idx):
    drop_ids = ID_mask[frame_idx]
    ddt.drop_det(Xdata=s, Ydata=means[frame_idx],
                                    thr_low=thr_low, thr_high=thr_high, plot_switch=True)
    for drop in droplets[drop_ids]:
        i = drop.frames.index(frame_idx)
        x = 0.5*(drop.starts[i] + drop.ends[i])
        y = 0.5*(thr_high + thr_low)
        plt.scatter(x,y,color='black',marker='^')
        plt.text(x,y + 0.25,drop.ID)
                
    return drop_ids


recurrencies = [d.recurrence for d in droplets]

# compute size and velocities
for d in droplets:
    _ = d.velocity
    _ = d.size

fig, ax = plt.subplots()
plt.hist(recurrencies)
plt.xlabel('times a droplet appears in the video')
plt.ylabel('number of droplets')
fig.tight_layout()
# Out:
# 100%|██████████| 599/599 [00:00<00:00, 57543.07it/s]
# <img src="data:image/png;base64,..." width="432">

# %%
recurrencies
# Out:
# [54,
#  106,
#  1,
#  17,
#  80,
#  12,
#  33,
#  7,
#  52,
#  62,
#  13,
#  37,
#  56,
#  24,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  4,
#  4,
#  1,
#  4,
#  6,
#  3,
#  3,
#  6,
#  7,
#  3,
#  1,
#  1,
#  4,
#  5,
#  1,
#  1,
#  2,
#  1,
#  1,
#  4,
#  6,
#  3,
#  2,
#  3,
#  1,
#  2,
#  6,
#  5,
#  1,
#  1,
#  1,
#  2,
#  6,
#  1,
#  6,
#  8,
#  4,
#  3,
#  3,
#  3,
#  7,
#  4,
#  1,
#  2,
#  2,
#  5,
#  30,
#  38,
#  10,
#  2,
#  2,
#  1,
#  1,
#  1,
#  5,
#  5,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  3,
#  4,
#  2,
#  1,
#  1,
#  3,
#  3,
#  4,
#  8,
#  5,
#  1,
#  1,
#  1,
#  1,
#  1,
#  4,
#  7,
#  3,
#  1,
#  1,
#  1,
#  1,
#  2,
#  7,
#  5,
#  1,
#  1,
#  1,
#  3,
#  5,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  2,
#  2,
#  5,
#  6,
#  1,
#  4,
#  8,
#  6,
#  2,
#  1,
#  1,
#  2,
#  6,
#  7,
#  3,
#  2,
#  2,
#  1,
#  4,
#  5,
#  3,
#  3,
#  3,
#  3,
#  6,
#  3,
#  2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  6,
#  5,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  3,
#  6,
#  4,
#  1,
#  1,
#  3,
#  4,
#  7,
#  1,
#  2,
#  1,
#  1,
#  2,
#  6,
#  6,
#  2,
#  1,
#  2,
#  1,
#  1,
#  1,
#  2,
#  5,
#  7,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  5,
#  8,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  6,
#  9,
#  8,
#  5,
#  1,
#  1,
#  1,
#  5,
#  5,
#  3]

# %%
# reload(plt)
# %matplotlib notebook
idx = 210
drops_in_frame(idx)
# Out:
# <img src="data:image/png;base64,..." width="1440">
# [697, 698]

# %%
drops_in_frame(idx + 1)
# Out:
# <img src="data:image/png;base64,..." width="1440">
# [695, 696]

# %%
drops_in_frame(idx + 2)
# Out:
# <img src="data:image/png;base64,..." width="1440">
# [693, 694]

# %%
droplets[1].frames
# Out:
# [597,
#  596,
#  595,
#  594,
#  593,
#  592,
#  591,
#  590,
#  589,
#  588,
#  587,
#  586,
#  585,
#  584,
#  583,
#  582,
#  581,
#  580,
#  579,
#  578,
#  577,
#  576,
#  575,
#  574,
#  573,
#  572,
#  571,
#  570,
#  569,
#  568,
#  567,
#  566,
#  565,
#  564,
#  563,
#  562,
#  561,
#  560,
#  559,
#  558,
#  557,
#  556,
#  555,
#  554,
#  553,
#  552,
#  551,
#  550,
#  549,
#  548,
#  547,
#  546,
#  545,
#  544,
#  543,
#  542,
#  541,
#  540,
#  539,
#  538,
#  537,
#  536,
#  535,
#  534,
#  533,
#  532,
#  531,
#  530,
#  529,
#  528,
#  527,
#  526,
#  525,
#  524,
#  523,
#  522,
#  521,
#  520,
#  519,
#  518,
#  517,
#  516,
#  515,
#  514,
#  513,
#  512,
#  511,
#  510,
#  509,
#  508,
#  507,
#  506,
#  505,
#  504,
#  503,
#  502,
#  501,
#  500,
#  499,
#  498,
#  497,
#  496,
#  495,
#  494,
#  493,
#  492]

# %% [markdown]
# ### Droplet statistics

# %%
q = np.sqrt(2*np.pi)

def gaus(x, mu, sigma):
    return np.exp(-(x - mu)**2/(2*sigma**2))/(sigma*q)

# kernel density estimation
def kde_plot(xs, centers, sigmas, min_sigma=0.01,**kwargs):
    ys = np.zeros_like(xs)
    for i,x in tqdm(enumerate(xs)):
        for j,c in enumerate(centers):
            ys[i] += gaus(x,c,max(sigmas[j],min_sigma))
    
    # normalize
    ys /= np.sum(ys)
    
    xlabel = kwargs.pop('xlabel',None)
    plt.figure()
    plt.plot(xs,ys,**kwargs)
    plt.xlabel(xlabel)
    plt.ylabel('probability')
    plt.tight_layout()
    
    return ys

# %%
# size

min_recurrence = 2

size_means = [d.size[0] for d in droplets if d.recurrence >= min_recurrence]
size_stds = [d.size[1] for d in droplets if d.recurrence >= min_recurrence]


# histogram
plt.figure()
plt.hist(size_means,bins=40)
plt.xlabel('droplet size [mm]')
plt.ylabel('counts')

print(len(size_means))
# Out:
# <img src="data:image/png;base64,..." width="432">
# 137

# %%
# kde plot

xs = np.linspace(0,10,10000)

kde_plot(xs, size_means, size_stds, min_sigma=0.1, xlabel='size [mm]')
# Out:
# 10000it [00:09, 1046.92it/s]
# <img src="data:image/png;base64,..." width="432">
# array([1.57720627e-06, 1.58429506e-06, 1.59141730e-06, ...,
#        1.64932406e-07, 1.64797498e-07, 1.64662715e-07])

# %%
# velocity

# at least 2 otherwise cannot compute velocity
min_recurrence = 2

velocity_means = [d.velocity[0] for d in droplets if d.recurrence >= min_recurrence]
velocity_stds = [d.velocity[1] for d in droplets if d.recurrence >= min_recurrence]

# histogram
plt.figure()
plt.hist(velocity_means,bins=40)
plt.xlabel('droplet velocity [mm/s]')
plt.ylabel('counts')

print(len(velocity_means))
# Out:
# <img src="data:image/png;base64,..." width="432">
# 132

# %%
# velocity - velocity_std correlation
plt.figure()
plt.scatter(velocity_means,velocity_stds)
plt.xlabel('droplet velocity [mm/s]')
plt.ylabel('velocity std')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0, 0.5, 'velocity std')

# %%
# kde plot

vs = np.linspace(6,12,10000)

kde_plot(vs, velocity_means, velocity_stds, min_sigma=0.1, xlabel='velocity [mm/s]')
# Out:
# 10000it [00:09, 1085.43it/s]
# <img src="data:image/png;base64,..." width="640">
# array([1.92251357e-05, 1.93289914e-05, 1.94331427e-05, ...,
#        4.34178144e-05, 4.32332270e-05, 4.30486182e-05])

# %%
# velocity - frame_id correlation

frames_idxs = [d.frames[-1] for d in droplets if d.recurrence >= min_recurrence]

plt.figure()
plt.scatter(frames_idxs, velocity_means)
plt.xlabel('frame_idx')
plt.ylabel('velocity [mm/s]')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0, 0.5, 'velocity [mm/s]')

# %%
# velocity - frame_id correlation identifying droplets

name = '2-12_B-ol3-aq7_v_vs_frame_id'

# color_list = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'black']

fig,ax = plt.subplots(figsize=(12,8))
for d in droplets:
    if d.recurrence >= min_recurrence:
#         plt.plot(d.frames[:-1], d.velocities, c=color_list[d.recurrence - min_recurrence])
        plt.plot(d.frames[:-1], d.velocities, color='blue')
    
plt.xlabel('frame index')
plt.ylabel('velocity [mm/s]')

fig.tight_layout()

fig.savefig(f'Report/Plots/{name}.pgf')
fig.savefig(f'Report/Plots/{name}.png')
# Out:
# <img src="data:image/png;base64,..." width="864">

# %%
# size - frame_id correlation identifying droplets

# color_list = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'black']

name = '2-12_B-ol3-aq7_size_vs_frame_id'

fig,ax = plt.subplots(figsize=(12,8))
for d in droplets:
    if d.recurrence >= min_recurrence:
#         plt.plot(d.frames[:-1], d.velocities, c=color_list[d.recurrence - min_recurrence])
        plt.plot(d.frames, d.sizes, color='blue')
    
plt.xlabel('frame index')
plt.ylabel('droplet size [mm]')

fig.tight_layout()

fig.savefig(f'Report/Plots/{name}.pgf')
fig.savefig(f'Report/Plots/{name}.png')
# Out:
# <img src="data:image/png;base64,..." width="864">

# %%
# velocity - position correlation

starts= [d.starts[-1] for d in droplets if d.recurrence >= min_recurrence]

plt.figure()
plt.scatter(starts, velocity_means)
plt.xlabel('start_point')
plt.ylabel('velocity [mm/s]')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0, 0.5, 'velocity [mm/s]')

# %%
# size - velocity correlation

plt.figure()
plt.scatter(size_means, velocity_means)
plt.xlabel('size [mm]')
plt.ylabel('velocity [mm/s]')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0, 0.5, 'velocity [mm/s]')

# %%
# velocity - recurrence correlation

recurrences = [d.recurrence for d in droplets if d.recurrence >= min_recurrence]

plt.figure()
plt.scatter(recurrences, velocity_means)
plt.xlabel('recurrence')
plt.ylabel('velocity [mm/s]')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'velocity [mm/s]')
